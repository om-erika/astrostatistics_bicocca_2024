# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import roc_curve
from sklearn.metrics import RocCurveDisplay
from tensorboard.plugins.hparams import api as hp

# %%
df = pd.read_csv("../solutions/galaxyquasar.csv")
df
# Out:
#               u         g         r         i         z   class        z1  \
# 0      18.97213  18.53676  18.58280  18.34936  18.29215     QSO  0.522819
# 1      19.24592  17.47646  16.47817  16.04472  15.68851  GALAXY  0.122846
# 2      19.43536  17.70268  16.91565  16.58327  16.39128  GALAXY  0.000000
# 3      19.31626  18.18312  17.39591  16.94549  16.65395  GALAXY  0.147435
# 4      19.28828  19.11188  18.88937  18.80013  18.49183     QSO  2.011455
# ...         ...       ...       ...       ...       ...     ...       ...
# 49995  19.37295  18.12382  17.39886  16.98503  16.70585  GALAXY  0.113016
# 49996  18.52021  16.88262  16.03280  15.56884  15.22454  GALAXY  0.085063
# 49997  18.62718  17.30876  16.87371  16.62399  16.42296  GALAXY  0.054429
# 49998  19.55140  18.27711  17.62101  17.21947  17.03347  GALAXY  0.112571
# 49999  18.80772  17.75751  17.40500  17.21650  17.12295  GALAXY  0.043652
#
#            zerr
# 0      0.000155
# 1      0.000028
# 2      0.000000
# 3      0.000009
# 4      0.000631
# ...         ...
# 49995  0.000011
# 49996  0.000014
# 49997  0.000008
# 49998  0.000009
# 49999  0.000007
#
# [50000 rows x 8 columns]

# %%
df['u-g'] = df['u']- df['g'] 
df['g-r'] = df['g']- df['r'] 
df['r-i'] = df['r']- df['i']
df['i-z'] = df['i']- df['z']

# %%
le = LabelEncoder()
# Assign unique integers: 1 QSO, 0 galaxy
df['class'] = le.fit_transform(df['class'] )
labels_class = le.inverse_transform(df['class'] )
class_names = le.classes_
print('Class names: ', class_names)
print('Labels: ', labels_class)
# Out:
# Class names:  ['GALAXY' 'QSO']
# Labels:  ['QSO' 'GALAXY' 'GALAXY' ... 'GALAXY' 'GALAXY' 'GALAXY']

# %%
neg, pos = np.bincount(df['class'])
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Total: 50000
#     Positive: 7134 (14.27% of total)

# %%
initial_bias = np.log([pos/neg])
initial_bias
# Out:
# array([-1.79320688])

# %%
scaler = StandardScaler().set_output(transform="pandas")
X_train, X_val, y_train, y_val = train_test_split(df.loc[:, 'u-g':'i-z'], df['class'], test_size=0.3, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=9)
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
# %load_ext tensorboard

# %%
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([5,10,15,20]))
HP_DROPOUT = hp.HParam('dropout', hp.Discrete([0.1, 0.2, 0.5]))
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['nadam', 'sgd']))
METRIC_BINARY_CROSSENTROPY = 'binary_crossentropy'

with tf.summary.create_file_writer('def_bias/hparam_tuning').as_default():
  hp.hparams_config(
    hparams=[HP_NUM_UNITS, HP_DROPOUT, HP_OPTIMIZER],
    metrics=[hp.Metric(METRIC_BINARY_CROSSENTROPY, display_name='Binary Crossentropy')]
  )

# %%
def validate_model(hparams):
  output_bias = tf.keras.initializers.Constant(initial_bias)
  model = keras.Sequential([
      tf.keras.layers.InputLayer(shape=(X_train.shape[-1],)),
      keras.layers.Dense(
          hparams[HP_NUM_UNITS], activation='relu'),
      keras.layers.Dropout(hparams[HP_DROPOUT]),
      keras.layers.Dense(1, activation='sigmoid',
                         bias_initializer=output_bias),
  ])

  model.compile(
      optimizer=hparams[HP_OPTIMIZER],
      loss=keras.losses.BinaryCrossentropy(),
      metrics=[keras.metrics.BinaryCrossentropy(name='binary crossentropy')])
  model.fit(X_train_scaled, y_train, epochs=1)
  _, binary_crossentropy = model.evaluate(X_val_scaled, y_val)
  return (binary_crossentropy)

# %%
def run(run_dir, hparams):
  with tf.summary.create_file_writer(run_dir).as_default():
    hp.hparams(hparams)  # record the values used in this trial
    binary_crossentropy = validate_model(hparams)
    tf.summary.scalar(METRIC_BINARY_CROSSENTROPY, binary_crossentropy, step=1)

# %%
session_num = 0

for num_units in HP_NUM_UNITS.domain.values:
  for dropout_rate in (HP_DROPOUT.domain.values):
    for optimizer in HP_OPTIMIZER.domain.values:
      hparams = {
          HP_NUM_UNITS: num_units,
          HP_DROPOUT: dropout_rate,
          HP_OPTIMIZER: optimizer,
      }
      run_name = "run-%d" % session_num
      print('--- Starting trial: %s' % run_name)
      print({h.name: hparams[h] for h in hparams})
      run('def_bias/hparam_tuning/' + run_name, hparams)
      session_num += 1
# Out:
# --- Starting trial: run-0
# {'num_units': 5, 'dropout': 0.1, 'optimizer': 'nadam'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - binary crossentropy: 0.2618 - loss: 0.2618
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary crossentropy: 0.1137 - loss: 0.1137
# --- Starting trial: run-1
# {'num_units': 5, 'dropout': 0.1, 'optimizer': 'sgd'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - binary crossentropy: 0.2844 - loss: 0.2844
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary crossentropy: 0.1625 - loss: 0.1625
# --- Starting trial: run-2
# {'num_units': 5, 'dropout': 0.2, 'optimizer': 'nadam'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - binary crossentropy: 0.4076 - loss: 0.4076
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary crossentropy: 0.1674 - loss: 0.1674
# --- Starting trial: run-3
# {'num_units': 5, 'dropout': 0.2, 'optimizer': 'sgd'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - binary crossentropy: 0.3051 - loss: 0.3051
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary crossentropy: 0.1612 - loss: 0.1612
# --- Starting trial: run-4
# {'num_units': 5, 'dropout': 0.5, 'optimizer': 'nadam'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - binary crossentropy: 0.3174 - loss: 0.3174
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary crossentropy: 0.1820 - loss: 0.1820
# --- Starting trial: run-5
# {'num_units': 5, 'dropout': 0.5, 'optimizer': 'sgd'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - binary crossentropy: 0.2892 - loss: 0.2892
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary crossentropy: 0.1752 - loss: 0.1752
# --- Starting trial: run-6
# {'num_units': 10, 'dropout': 0.1, 'optimizer': 'nadam'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - binary crossentropy: 0.2175 - loss: 0.2175
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary crossentropy: 0.1055 - loss: 0.1055
# --- Starting trial: run-7
# {'num_units': 10, 'dropout': 0.1, 'optimizer': 'sgd'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - binary crossentropy: 0.2927 - loss: 0.2927
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary crossentropy: 0.1513 - loss: 0.1513
# --- Starting trial: run-8
# {'num_units': 10, 'dropout': 0.2, 'optimizer': 'nadam'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - binary crossentropy: 0.3454 - loss: 0.3454
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary crossentropy: 0.1218 - loss: 0.1218
# --- Starting trial: run-9
# {'num_units': 10, 'dropout': 0.2, 'optimizer': 'sgd'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - binary crossentropy: 0.2820 - loss: 0.2820
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - binary crossentropy: 0.1486 - loss: 0.1486
# --- Starting trial: run-10
# {'num_units': 10, 'dropout': 0.5, 'optimizer': 'nadam'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - binary crossentropy: 0.3479 - loss: 0.3479
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary crossentropy: 0.1458 - loss: 0.1458
# --- Starting trial: run-11
# {'num_units': 10, 'dropout': 0.5, 'optimizer': 'sgd'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - binary crossentropy: 0.3176 - loss: 0.3176
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary crossentropy: 0.1621 - loss: 0.1621
# --- Starting trial: run-12
# {'num_units': 15, 'dropout': 0.1, 'optimizer': 'nadam'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - binary crossentropy: 0.3655 - loss: 0.3655
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary crossentropy: 0.1225 - loss: 0.1225
# --- Starting trial: run-13
# {'num_units': 15, 'dropout': 0.1, 'optimizer': 'sgd'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - binary crossentropy: 0.3047 - loss: 0.3047
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary crossentropy: 0.1569 - loss: 0.1569
# --- Starting trial: run-14
# {'num_units': 15, 'dropout': 0.2, 'optimizer': 'nadam'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - binary crossentropy: 0.2532 - loss: 0.2532
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary crossentropy: 0.1009 - loss: 0.1009
# --- Starting trial: run-15
# {'num_units': 15, 'dropout': 0.2, 'optimizer': 'sgd'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - binary crossentropy: 0.2867 - loss: 0.2867
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary crossentropy: 0.1514 - loss: 0.1514
# --- Starting trial: run-16
# {'num_units': 15, 'dropout': 0.5, 'optimizer': 'nadam'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - binary crossentropy: 0.3464 - loss: 0.3464
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary crossentropy: 0.1098 - loss: 0.1098
# --- Starting trial: run-17
# {'num_units': 15, 'dropout': 0.5, 'optimizer': 'sgd'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - binary crossentropy: 0.2865 - loss: 0.2865
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary crossentropy: 0.1606 - loss: 0.1606
# --- Starting trial: run-18
# {'num_units': 20, 'dropout': 0.1, 'optimizer': 'nadam'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - binary crossentropy: 0.2511 - loss: 0.2511
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary crossentropy: 0.0884 - loss: 0.0884
# --- Starting trial: run-19
# {'num_units': 20, 'dropout': 0.1, 'optimizer': 'sgd'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - binary crossentropy: 0.2811 - loss: 0.2811
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary crossentropy: 0.1538 - loss: 0.1538
# --- Starting trial: run-20
# {'num_units': 20, 'dropout': 0.2, 'optimizer': 'nadam'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - binary crossentropy: 0.2907 - loss: 0.2907
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary crossentropy: 0.0935 - loss: 0.0935
# --- Starting trial: run-21
# {'num_units': 20, 'dropout': 0.2, 'optimizer': 'sgd'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - binary crossentropy: 0.3005 - loss: 0.3005
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary crossentropy: 0.1473 - loss: 0.1473
# --- Starting trial: run-22
# {'num_units': 20, 'dropout': 0.5, 'optimizer': 'nadam'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - binary crossentropy: 0.3024 - loss: 0.3024
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary crossentropy: 0.0975 - loss: 0.0975
# --- Starting trial: run-23
# {'num_units': 20, 'dropout': 0.5, 'optimizer': 'sgd'}
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - binary crossentropy: 0.2850 - loss: 0.2850
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary crossentropy: 0.1613 - loss: 0.1613

# %%
# %tensorboard --logdir def_bias/hparam_tuning --host localhost --port 7935
# Out:
#       <iframe id="tensorboard-frame-7ac6da849ec52f42" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7ac6da849ec52f42");
#           const url = new URL("/", window.location);
#           const port = 7935;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
tuned_num_units = 20
tuned_dropout = 0.1
tuned_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
METRICS = [
      keras.metrics.BinaryCrossentropy(name='cross entropy'),
      keras.metrics.BinaryAccuracy(name='binary accuracy'),
      keras.metrics.Precision(name='precision'),
      
    # same as model's loss
]

def make_model(metrics=METRICS, output_bias=None):
  output_bias = tf.keras.initializers.Constant(initial_bias)
  model = keras.Sequential([
      tf.keras.layers.InputLayer(shape=(X_train.shape[-1],)),
      keras.layers.Dense(
          tuned_num_units, activation='relu',
          ),
      keras.layers.Dropout(tuned_dropout),
      keras.layers.Dense(1, activation='sigmoid',
                         bias_initializer=output_bias),
  ])

  model.compile(
      optimizer=tuned_optimizer,
      loss=keras.losses.BinaryCrossentropy(),
      metrics=metrics)
  #print(metrics)
  return model

# %%
model = make_model()
model.summary()
# Out:
# Model: "sequential_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_48 (Dense)                     │ (None, 20)                  │             100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_24 (Dropout)                 │ (None, 20)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_49 (Dense)                     │ (None, 1)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 121 (484.00 B)
#  Trainable params: 121 (484.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train_scaled, y_train, epochs=20, validation_data=(X_val_scaled, y_val))
# Out:
# Epoch 1/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - binary accuracy: 0.9338 - cross entropy: 0.1989 - loss: 0.1989 - precision: 0.8868 - val_binary accuracy: 0.9828 - val_cross entropy: 0.0841 - val_loss: 0.0841 - val_precision: 0.9613
# Epoch 2/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - binary accuracy: 0.9799 - cross entropy: 0.0817 - loss: 0.0817 - precision: 0.9486 - val_binary accuracy: 0.9822 - val_cross entropy: 0.0769 - val_loss: 0.0769 - val_precision: 0.9585
# Epoch 3/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - binary accuracy: 0.9811 - cross entropy: 0.0760 - loss: 0.0760 - precision: 0.9514 - val_binary accuracy: 0.9820 - val_cross entropy: 0.0751 - val_loss: 0.0751 - val_precision: 0.9584
# Epoch 4/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - binary accuracy: 0.9811 - cross entropy: 0.0770 - loss: 0.0770 - precision: 0.9507 - val_binary accuracy: 0.9821 - val_cross entropy: 0.0746 - val_loss: 0.0746 - val_precision: 0.9571
# Epoch 5/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - binary accuracy: 0.9822 - cross entropy: 0.0703 - loss: 0.0703 - precision: 0.9503 - val_binary accuracy: 0.9825 - val_cross entropy: 0.0741 - val_loss: 0.0741 - val_precision: 0.9538
# Epoch 6/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - binary accuracy: 0.9827 - cross entropy: 0.0702 - loss: 0.0702 - precision: 0.9561 - val_binary accuracy: 0.9820 - val_cross entropy: 0.0740 - val_loss: 0.0740 - val_precision: 0.9580
# Epoch 7/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - binary accuracy: 0.9811 - cross entropy: 0.0740 - loss: 0.0740 - precision: 0.9533 - val_binary accuracy: 0.9828 - val_cross entropy: 0.0734 - val_loss: 0.0734 - val_precision: 0.9569
# Epoch 8/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - binary accuracy: 0.9831 - cross entropy: 0.0656 - loss: 0.0656 - precision: 0.9538 - val_binary accuracy: 0.9829 - val_cross entropy: 0.0726 - val_loss: 0.0726 - val_precision: 0.9565
# Epoch 9/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - binary accuracy: 0.9818 - cross entropy: 0.0710 - loss: 0.0710 - precision: 0.9483 - val_binary accuracy: 0.9829 - val_cross entropy: 0.0725 - val_loss: 0.0725 - val_precision: 0.9531
# Epoch 10/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - binary accuracy: 0.9814 - cross entropy: 0.0755 - loss: 0.0755 - precision: 0.9524 - val_binary accuracy: 0.9831 - val_cross entropy: 0.0720 - val_loss: 0.0720 - val_precision: 0.9549
# Epoch 11/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - binary accuracy: 0.9836 - cross entropy: 0.0660 - loss: 0.0660 - precision: 0.9549 - val_binary accuracy: 0.9820 - val_cross entropy: 0.0732 - val_loss: 0.0732 - val_precision: 0.9575
# Epoch 12/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - binary accuracy: 0.9821 - cross entropy: 0.0733 - loss: 0.0733 - precision: 0.9508 - val_binary accuracy: 0.9825 - val_cross entropy: 0.0724 - val_loss: 0.0724 - val_precision: 0.9581
# Epoch 13/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - binary accuracy: 0.9813 - cross entropy: 0.0733 - loss: 0.0733 - precision: 0.9514 - val_binary accuracy: 0.9823 - val_cross entropy: 0.0722 - val_loss: 0.0722 - val_precision: 0.9589
# Epoch 14/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - binary accuracy: 0.9837 - cross entropy: 0.0615 - loss: 0.0615 - precision: 0.9541 - val_binary accuracy: 0.9831 - val_cross entropy: 0.0706 - val_loss: 0.0706 - val_precision: 0.9566
# Epoch 15/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - binary accuracy: 0.9826 - cross entropy: 0.0694 - loss: 0.0694 - precision: 0.9544 - val_binary accuracy: 0.9831 - val_cross entropy: 0.0707 - val_loss: 0.0707 - val_precision: 0.9579
# Epoch 16/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - binary accuracy: 0.9833 - cross entropy: 0.0658 - loss: 0.0658 - precision: 0.9559 - val_binary accuracy: 0.9829 - val_cross entropy: 0.0708 - val_loss: 0.0708 - val_precision: 0.9570
# Epoch 17/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - binary accuracy: 0.9817 - cross entropy: 0.0713 - loss: 0.0713 - precision: 0.9458 - val_binary accuracy: 0.9831 - val_cross entropy: 0.0711 - val_loss: 0.0711 - val_precision: 0.9592
# Epoch 18/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - binary accuracy: 0.9829 - cross entropy: 0.0682 - loss: 0.0682 - precision: 0.9591 - val_binary accuracy: 0.9836 - val_cross entropy: 0.0701 - val_loss: 0.0701 - val_precision: 0.9563
# Epoch 19/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - binary accuracy: 0.9832 - cross entropy: 0.0684 - loss: 0.0684 - precision: 0.9552 - val_binary accuracy: 0.9831 - val_cross entropy: 0.0701 - val_loss: 0.0701 - val_precision: 0.9579
# Epoch 20/20
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - binary accuracy: 0.9842 - cross entropy: 0.0684 - loss: 0.0684 - precision: 0.9587 - val_binary accuracy: 0.9837 - val_cross entropy: 0.0698 - val_loss: 0.0698 - val_precision: 0.9555

# %%
train_predictions = model.predict(X_train_scaled)
val_predictions = model.predict(X_val_scaled)
test_predictions = model.predict(X_test_scaled)
# Out:
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
def plot_cm(labels, predictions, threshold=0.5):
  cm = confusion_matrix(labels, predictions > threshold)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix with threshold = {:.2f}'.format(threshold))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('Galaxies correctly detected as galaxies (True Positives): ', cm[0][0])
  print('Galaxies mistakely detected as QSO (False Positives): ', cm[0][1])
  print('QSO mistakely detected as galaxies (False Negatives): ', cm[1][0])
  print('QSO  correctly detected as QSO (True Negatives): ', cm[1][1])
  print('Total galaxies: ', np.sum(cm[0]))
  print('Total QSO: ', np.sum(cm[1]))

# %%
val_results = model.evaluate(X_val_scaled, y_val, verbose=0)
for name, value in zip(model.metrics_names, val_results):
  print(name, ': ', value)
print()

plot_cm(y_val, val_predictions, threshold = 0.5)
# Out:
# loss :  0.0698130801320076
# compile_metrics :  0.0698130801320076
#
# Galaxies correctly detected as galaxies (True Positives):  12717
# Galaxies mistakely detected as QSO (False Positives):  95
# QSO mistakely detected as galaxies (False Negatives):  150
# QSO  correctly detected as QSO (True Negatives):  2038
# Total galaxies:  12812
# Total QSO:  2188

# %%
test_results = model.evaluate(X_test_scaled, y_test, verbose=0)
for name, value in zip(model.metrics_names, test_results):
  print(name, ': ', value)
print()

plot_cm(y_test, test_predictions, threshold = 0.5)
# Out:
# loss :  0.07451477646827698
# compile_metrics :  0.07451477646827698
#
# Galaxies correctly detected as galaxies (True Positives):  5967
# Galaxies mistakely detected as QSO (False Positives):  41
# QSO mistakely detected as galaxies (False Negatives):  80
# QSO  correctly detected as QSO (True Negatives):  912
# Total galaxies:  6008
# Total QSO:  992

# %%
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(121)
ax.plot(history.history['binary accuracy'])
ax.plot(history.history['val_binary accuracy'])
ax.set_title('model binary accuracy')
ax.set_ylabel('binary accuracy')
ax.set_xlabel('epoch')
ax.legend(['train', 'val'], loc='upper left')

ax1 = fig.add_subplot(122)
ax1.plot(history.history['precision'])
ax1.plot(history.history['val_precision'])
ax1.set_title('model precision')
ax1.set_ylabel('precision')
ax1.set_xlabel('epoch')
ax1.legend(['train', 'val'], loc='upper left')

plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, model.predict(X_test_scaled) > 0.5)
print(report)
# Out:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6008
#            1       0.96      0.92      0.94       992
#
#     accuracy                           0.98      7000
#    macro avg       0.97      0.96      0.96      7000
# weighted avg       0.98      0.98      0.98      7000
